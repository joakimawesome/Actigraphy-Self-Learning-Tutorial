# %%
import os
import pandas as pd

# %%
path_emr = '../data/STAGES EMR 20200709 Final deidentified.xlsx'

target_cols = ['Subject Id',
               'Final Phys Diagn Hypersomnia',
               'Final Phys Diagn Srbd',
               'Final Phys Diagn Insomnia',
               'Final Phys Diagn Parasomnia',
               'Final Phys Diagn Circadian',
               'Final Phys Diagn Movement Disorder',
               'Final Phys Diagn Other']

df = pd.read_excel(path_emr, usecols=target_cols).dropna(axis=0)
df
# Out:
#      Subject Id  Final Phys Diagn Hypersomnia  Final Phys Diagn Srbd  \
# 0     BOGN00001                           0.0                    1.0
# 1     BOGN00002                           0.0                    1.0
# 2     BOGN00003                           0.0                    1.0
# 3     BOGN00004                           0.0                    0.0
# 5     BOGN00006                           0.0                    1.0
# ...         ...                           ...                    ...
# 1959  STNF00493                           0.0                    0.0
# 1960  STNF00494                           0.0                    1.0
# 1961  STNF00495                           0.0                    1.0
# 1962  STNF00496                           0.0                    1.0
# 1963  STNF00497                           0.0                    1.0
#
#       Final Phys Diagn Insomnia  Final Phys Diagn Parasomnia  \
# 0                           0.0                          0.0
# ...

# %%
df['insomnia'] = df['Final Phys Diagn Insomnia'].astype(int)
df
# Out:
#      Subject Id  Final Phys Diagn Hypersomnia  Final Phys Diagn Srbd  \
# 0     BOGN00001                           0.0                    1.0
# 1     BOGN00002                           0.0                    1.0
# 2     BOGN00003                           0.0                    1.0
# 3     BOGN00004                           0.0                    0.0
# 5     BOGN00006                           0.0                    1.0
# ...         ...                           ...                    ...
# 1959  STNF00493                           0.0                    0.0
# 1960  STNF00494                           0.0                    1.0
# 1961  STNF00495                           0.0                    1.0
# 1962  STNF00496                           0.0                    1.0
# 1963  STNF00497                           0.0                    1.0
#
#       Final Phys Diagn Insomnia  Final Phys Diagn Parasomnia  \
# 0                           0.0                          0.0
# ...

# %%
df.to_csv('../data/patient_diag_labels.csv')
